# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

mpl.rcParams.update({'font.size': 14})
prefix_path = '../data/training_logs/'
############################################### row1, col1 ########################################
with open(prefix_path + 'ur50_all1ep_training_loss/all1ep_clm_150M/run-gpt_157m_1024_noreg_lr4e-4_all1ep-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_clm_all_150M = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_training_loss/all1ep_clm_3b/run-gpt_3b_1024_noreg_all1ep_bf16-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_clm_all_3B = pd.read_csv(f) 

with open(prefix_path + 'ur50_all1ep_training_loss/ur50_clm_150M/run-gpt_157m_1024_noreg_lr4e-4_ur50-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_clm_ur50_150M = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_training_loss/ur50_clm_3b/run-gpt_3b_1024_noreg_ur50_bf16-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_clm_ur50_3B = pd.read_csv(f) 

##################################################### row2, col1 ########################################
with open(prefix_path + 'ur50_all1ep_training_loss/all1ep_mlm_3b/run-mlm_3b_all1ep_noreg_tk200b_cl1024_bsz1m_scratch-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_mlm_all_3B = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_training_loss/all1ep_mlm_150M/run-mlm_154M_all1ep-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_mlm_all_150M = pd.read_csv(f) 

with open(prefix_path + 'ur50_all1ep_training_loss/ur50_mlm_3b_full_shuffle/run-mlm_3b_overfit_bsz1m_2-tag-lm-loss-training_lm loss vs tokens.csv') as f:
   training_mlm_ur50_3B = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_training_loss/ur50_mlm_150M/run-mlm_154M_ur50-tag-lm-loss-validation_valid_lm loss validation vs tokens.csv') as f:
   training_mlm_ur50_150M = pd.read_csv(f) 
#################################################row1, col2 ################################################
with open(prefix_path + 'ur50_all1ep_valid_loss/all1ep_clm_3b/run-gpt_3b_1024_noreg_all1ep_bf16-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_clm_all_3B = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_valid_loss/all1ep_clm_150M/run-gpt_157m_1024_noreg_lr4e-4_all1ep-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_clm_all_150M = pd.read_csv(f) 

with open(prefix_path + 'ur50_all1ep_valid_loss/ur50_clm_3b/run-gpt_3b_1024_noreg_ur50_bf16-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_clm_ur50_3B = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_valid_loss/ur50_clm_150M/run-gpt_157m_1024_noreg_lr4e-4_ur50-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_clm_ur50_150M = pd.read_csv(f) 

#################################################row2, col2 ##################################################
#with open('ur50_all1ep_valid_loss/all1ep_mlm_3b/run-mlm_3b_all1ep_noreg_tk200b_cl1024_bsz1m_scratch-tag-lm-loss-validation_valid_lm loss validation vs tokens (1).csv') as f:
with open(prefix_path + 'ur50_all1ep_valid_loss/all1ep_mlm_3b/run-mlm_3b_all1ep_noreg_tk200b_cl1024_bsz1m_scratch-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_mlm_all_3B = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_valid_loss/all1ep_mlm_150M/run-mlm_154M_1ep-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_mlm_all_150M = pd.read_csv(f) 

#with open('ur50_all1ep_valid_loss/ur50_mlm_3b/run-mlm_3b_ur50_noreg_tk200b_cl1024_bsz1m_scratch-tag-lm-loss-validation_valid_lm loss validation vs tokens.csv') as f:
with open(prefix_path + 'ur50_all1ep_valid_loss/ur50_mlm_3b_full_shuffle/run-mlm_3b_overfit_bsz1m_2-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_mlm_ur50_3B = pd.read_csv(f) 
with open(prefix_path + 'ur50_all1ep_valid_loss/ur50_mlm_150M/run-mlm_154M_ur50_2-tag-lm-loss-validation_valid_lm loss validation ppl vs tokens.csv') as f:
   valid_mlm_ur50_150M = pd.read_csv(f) 
   

# Create the figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 7))
colors = ['#1f77b4', 'orange', '#9ecae1', '#ffd700' ]
# Plot the training loss of different model sizes
axs[0, 0].plot(training_clm_ur50_150M['Step'], training_clm_ur50_150M['Value'], label='UR50/S-150M', color=colors[3])
axs[0, 0].plot(training_clm_all_150M['Step'], training_clm_all_150M['Value'], label='UniMeta200B-150M', color=colors[1])
axs[0, 0].plot(training_clm_ur50_3B['Step'], training_clm_ur50_3B['Value'], label='UR50/S-3B', color=colors[2])
axs[0, 0].plot(training_clm_all_3B['Step'], training_clm_all_3B['Value'], label='UniMeta200B-3B', color=colors[0])
axs[0, 0].set_title('Training Loss')
axs[0, 0].legend(fontsize=12)
xposs = [1.54e10 * (i+1) for i in range(14)]
xlabels = []
for i, xposlabel in enumerate(xposs):
   xposl = int(xposlabel/1e9)
   xposl = str(xposl) + 'B'
   xlabels.append(xposl)
axs[0,0].set_xticks(xposs[::4])
axs[0,0].set_xticklabels(xlabels[::4])
axs[0,0].set_xticklabels([])
axs[0,0].set_ylabel('Causal Language Model', fontsize=12)

# Plot the validation loss
axs[0, 1].plot(valid_clm_ur50_150M['Step'], valid_clm_ur50_150M['Value'], label='UR50-150M', color=colors[3])
axs[0, 1].plot(valid_clm_all_150M['Step'], valid_clm_all_150M['Value'], label='UniMeta-150M', color=colors[1])
axs[0, 1].plot(valid_clm_ur50_3B['Step'], valid_clm_ur50_3B['Value'], label='UR50-3B', color=colors[2])
axs[0, 1].plot(valid_clm_all_3B['Step'], valid_clm_all_3B['Value'], label='UniMeta-3B', color=colors[0])
axs[0, 1].set_title('Validation Perplexity')
xposs = [1.54e10 * (i+1) for i in range(14)]
xlabels = []
for i, xposlabel in enumerate(xposs):
   xposl = int(xposlabel/1e9)
   xposl = str(xposl) + 'B\n(' + str(i+1) + ')'
   xlabels.append(xposl)
axs[0,1].set_xticks(xposs[::4])
axs[0,1].set_xticklabels(xlabels[::4])
axs[0,1].set_xticklabels([])


axs[1, 0].plot(training_mlm_ur50_150M['Step'], training_mlm_ur50_150M['Value'], label='UR50-150M', color=colors[3])
axs[1, 0].plot(training_mlm_all_150M['Step'], training_mlm_all_150M['Value'], label='UniMeta-150M', color=colors[1])
axs[1, 0].plot(training_mlm_ur50_3B['Step'], training_mlm_ur50_3B['Value'], label='UR50-3B', color=colors[2])
axs[1, 0].plot(training_mlm_all_3B['Step'], training_mlm_all_3B['Value'], label='UniMeta-3B', color=colors[0])
axs[1, 0].set_ylim([1.6, 2.8])
axs[1, 0].set_ylabel('Masked Language Model', fontsize=12)
xposs = [1.54e10 * (i+1) for i in range(14)]
xlabels = []
for i, xposlabel in enumerate(xposs):
   xposl = int(xposlabel/1e9)
   xposl = str(xposl) + 'B'
   xlabels.append(xposl)
axs[1,0].set_xticks(xposs[::4])
axs[1,0].set_xticklabels(xlabels[::4])
axs[1,0].set_xlabel('Tokens')

axs[1, 1].plot(valid_mlm_ur50_150M['Step'], valid_mlm_ur50_150M['Value'], label='UR50-150M', color=colors[3])
axs[1, 1].plot(valid_mlm_all_150M['Step'], valid_mlm_all_150M['Value'], label='UniMeta-150M', color=colors[1])
axs[1, 1].plot(valid_mlm_ur50_3B['Step'], valid_mlm_ur50_3B['Value'], label='UR50-3B', color=colors[2])
axs[1, 1].plot(valid_mlm_all_3B['Step'], valid_mlm_all_3B['Value'], label='UniMeta-3B', color=colors[0])
axs[1, 1].set_ylim([6, 13])
xlabels = []
for i, xposlabel in enumerate(xposs):
   xposl = int(xposlabel/1e9)
   xposl = str(xposl) + 'B\n(' + str(i+1) + ')'
   xlabels.append(xposl)
axs[1,1].set_xticks(xposs[::4])
axs[1,1].set_xticklabels(xlabels[::4])
axs[1,1].set_xlabel('Tokens\n(UR50/S Epochs)')

# Adjust the spacing between subplots
labels = ['UniMeta-3B', 'UniMeta-150M', 'UR50-3B', 'UR50-150M']
handles = [plt.Line2D([], [], color=colors[0]), 
           plt.Line2D([], [], color=colors[1]),
           plt.Line2D([], [], color=colors[2]),
           plt.Line2D([], [], color=colors[3])]

# Show the plot
plt.show()
